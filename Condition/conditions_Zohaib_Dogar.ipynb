# %%
#if condition
#variable 1
x=5
if(x>3):
  print("pakistan")
#variable 2
marks=45
if(marks<50):
  print("ja mera putar chuti kr")
#variable 3
name="dogar"
if(name=="Dogar"):
  print("good boy")
#variable 4
num1=36
if(num1==6*6):
  print(" it is square of 6")
#variable 5
number = 10
if number > 0:
  print("The number is positive")
#variable 6
  text = ""
if not text:
  print("The string is empty")
#variable 7
  age = 16
  license = True
if age >= 18 and license:
  print("You are eligible to drive")
#variable 8
runs=85
if runs>70:
  print("good player")
  #variable 9
num1=int(input("enter a number"))
if num1%2==1:
  print(num1, "is odd number")
#variable 10
num2=int(input("enter a number"))
if num2%2==0:
  print(num2, "is even number")
# Out:
# pakistan
# ja mera putar chuti kr
#  it is square of 6
# The number is positive
# The string is empty
# good player
# enter a number9
# 9 is odd number
# enter a number8
# 8 is even number

# %%
#if else condition
#variable 1
num1=int(input("enter a number"))
if num1%2==1:
  print(num1, "is odd number")
else:
  print(num1, "is even number")
#variable 2
num2=int(input("enter a number"))
if num2%2==0:
  print(num2, "is even number")
else:
  print(num2, "is odd number")
#variable 3
age=int(input("enter your age"))
if age>=18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
#variable 4
num=int(input("enter a number"))
if num>0:
  print(num, "is a positive number")
else:
  print(num, "is a negative number")
#variable 5
marks=int(input("enter your marks"))
if marks>=90:
  print("your grade is A")
else:
  print("your grade is B")
#variable 6
speed=int(input("enter your bowling speed"))
if speed>=140:
  print("fast bowler")
else:
  print("slow bowler")
  #variable 7
name="dogar"
if name=="dogar":
  print("good boy")
else:
  print("bad boy")
#variable 8
num=5
if num<0:
  print(num, "is a negative number")
else:
  print(num, "is a positive number")
#variable 9
age=int(input("enter your age"))
if age>=18:
  print("you are eligible to drive")
else:
  print("mera puttar thora sabar kr")
#variable 10
inst="free"
if inst=="free":
  print("zain will teach ")
else:
  print("eman will teach")
# Out:
# enter a number4
# 4 is even number
# enter a number7
# 7 is odd number
# enter your age21
# you are eligible to vote
# enter a number65
# 65 is a positive number
# enter your marks97
# your grade is A
# enter your bowling speed145
# fast bowler
# good boy
# 5 is a positive number
# enter your age19
# you are eligible to drive
# zain will teach

# %%
#elif condition
#variable 1
marks=int(input("enter your marks"))
if marks>=90:
  print("your grade is A")
elif marks>=80:
  print("your grade is B")
else:
  print("your grade is C")
#variable 2
num=int(input("enter a number"))
if num>0:
  print(num, "is a positive number")
elif num<0:
  print(num, "is a negative number")
else:
  print(num, "is zero")
#variable 3
age=int(input("enter your age"))
if age>=18:
  print("you are eligible to vote")
elif age>=13:
  print("you are eligible to play")
else:
  print("you are not eligible")
#variable 4
speed=int(input("enter your bowling speed"))
if speed>=140:
  print("fast bowler")
elif speed>=120:
  print("medium bowler")
else:
  print("slow bowler")
#variable 5
num=78
if num>70:
  print(num, "passing number")
elif num<70 and num<60:
  print(num, "is a good number")
else:
  print(num, "is failure")
#variable 6
cgpa=float(input("enter your cgpa"))
if cgpa>=3.8:
  print("eligible for scholorship")
elif cgpa<=3.79 and cgpa>3.6:
  print("sochty hain kuch")
else:
  print("mehnat kr bchy ")
#variable 7
day = int(input("Enter a number (1-7) "))
if day == 1:
  print("Sunday")
elif day == 2:
  print("Monday")
elif day == 3:
  print("Tuesday")
elif day == 4:
  print("Wednesday")
elif day == 5:
  print("Thursday")
elif day == 6:
  print("Friday")
elif day == 7:
  print("Saturday")
else:
  print("Invalid day number")
#variable 8
aage= int(input("Enter your age: "))
if aage < 13:
  print("Child")
elif aage < 18:
  print("Teenager")
elif aage < 60:
  print("Adult")
else:
  print("Senior Citizen")
#variable 9
income = 4789087
if income <= 250000:
  print("No tax")
elif income <= 500000:
  print("5% tax")
elif income <= 1000000:
  print("10% tax")
else:
  print("20% tax")
#variable 10
amount =750
if amount >= 1000:
  discount = 0.10
elif amount >= 500:
  discount = 0.05
else:
  discount = 0
# Out:
# enter your marks67
# your grade is C
# enter a number7
# 7 is a positive number
# enter your age19
# you are eligible to vote
# enter your bowling speed155
# fast bowler
# 78 passing number
# enter your cgpa3.90
# eligible for scholorship
# Enter a number (1-7) 6
# Friday
# Enter your age: 21
# Adult
# 20% tax

# %% [markdown]
# Importing Dataset

# %%
import pandas as pd
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    Unnamed: 0  Age Sex ChestPainType  Unnamed: 4  Hypertension  Unnamed: 6  \
# 0           1   40   M           ATA         NaN           140         NaN
# 1           2   49   F           NAP         NaN           160         NaN
# 2           3   37   M           ATA         NaN           130         NaN
# 3           4   48   F           ASY         NaN           138         NaN
# 4           5   54   M           NAP         NaN           150         NaN
#
#    Cholesterol FastingBS RestingECG  MaxHR ExerciseAngina  Oldpeak ST_Slope  \
# 0          289         N     Normal    172              N      0.0       Up
# 1          180         N     Normal    156              N      1.0     Flat
# 2          283         N         ST     98              N      0.0       Up
# 3          214         N     Normal    108              Y      1.5     Flat
# 4          195         N     Normal    122              N      0.0       Up
#
#    HeartDisease  KidneyFailure
# 0             0              0
# 1             1              0
# 2             0              0
# 3             1              0
# 4             0              0

# %% [markdown]
# Training Data

# %%
x = df[["Age"]]
y = df[["Cholesterol"]]

# %%
x.head()
# Out:
# 0    40
# 1    49
# 2    37
# 3    48
# 4    54
# Name: Age, dtype: int64

# %%
y.head()
# Out:
#    Cholesterol
# 0          289
# 1          180
# 2          283
# 3          214
# 4          195

# %% [markdown]
# Splitting Data

# %%
x_train , x_test , y_train , y_test = x[0:50] , x[50:] , y[0:50] , y[50:]

# %% [markdown]
# Fitting Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train)
plt.plot(x_train,model.predict(x_train))
plt.xlabel("Age")
plt.ylabel("Cholesterol")
plt.show()

# %% [markdown]
# Testing and Evaluating

# %%
model.score(x_train,y_train)
# Out:
# 0.014917517606614528

# %%
model.score(x_test,y_test)
# Out:
# -0.2904917072931046

# %% [markdown]
# Prediction

# %%
model.predict([[50]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[249.08087501]])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Function to initialize centroids randomly
def initialize_centroids(X, k):
    return X[np.random.choice(X.shape[0], k, replace=False)]

# Function to assign points to nearest centroid
def assign_clusters(X, centroids):
    clusters = []
    for point in X:
        distances = [np.linalg.norm(point - centroid) for centroid in centroids]
        clusters.append(np.argmin(distances))
    return np.array(clusters)

# Function to update centroids
def update_centroids(X, clusters, k):
    new_centroids = []
    for cluster_id in range(k):
        cluster_points = X[clusters == cluster_id]
        if len(cluster_points) > 0:
            new_centroids.append(cluster_points.mean(axis=0))
        else:
            new_centroids.append(np.zeros(X.shape[1]))  # Handle empty clusters
    return np.array(new_centroids)

# K-means function
def k_means(X, k, max_iters=100, tol=1e-4):
    centroids = initialize_centroids(X, k)
    for i in range(max_iters):
        clusters = assign_clusters(X, centroids)
        new_centroids = update_centroids(X, clusters, k)
        if np.linalg.norm(new_centroids - centroids) < tol:
            break
        centroids = new_centroids
    return centroids, clusters

#  data for clustering
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=1.0, random_state=42)

#  Run K-means
k = 4
centroids, clusters = k_means(X, k)

#  Visualize the results
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='red', marker='X')  # Centroids
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# experiment1

# %%
from sklearn.datasets import make_blobs

# Simulate star data
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=1.0, random_state=42)
centroids, clusters = k_means(X, k=4)

# Visualize results
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='red', marker='X')
plt.title("Clustering Stars in Space")
plt.show()

# %% [markdown]
# experiment 2

# %%
# Simulate network data
X, _ = make_blobs(n_samples=500, centers=3, cluster_std=1.5, random_state=42)
centroids, clusters = k_means(X, k=3)

plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='cool')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='black', marker='X')
plt.title("Clustering Network Activities")
plt.show()

# %% [markdown]
# experiment3

# %%
# Simulate animal data
X, _ = make_blobs(n_samples=200, centers=3, cluster_std=1.2, random_state=0)
centroids, clusters = k_means(X, k=3)

plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='plasma')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='white', marker='X')
plt.title("Clustering Animals by Traits")
plt.show()

# %% [markdown]
# experiment4

# %%
# Simulate plant data
X, _ = make_blobs(n_samples=250, centers=4, cluster_std=0.8, random_state=3)
centroids, clusters = k_means(X, k=4)

plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='spring')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='black', marker='X')
plt.title("Clustering Plants by Features")
plt.show()

# %% [markdown]
# experiment5

# %%
# Simulate alien signals
X, _ = make_blobs(n_samples=400, centers=5, cluster_std=1.0, random_state=6)
centroids, clusters = k_means(X, k=5)

plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='rainbow')
plt.scatter(centroids[:, 0], centroids[:, 1], s=200, c='yellow', marker='X')
plt.title("Clustering Alien Signals")
plt.show()

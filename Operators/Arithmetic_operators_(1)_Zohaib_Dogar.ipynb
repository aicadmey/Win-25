# %%
num1=6
num2=3
num3=8
num4=4
num5=10
num6=5
num7=16
num8=8
num9=27
num10=9
#addition
print("addition of given numbers is :")
print(num1+num2)
print(num3+num4)
print(num5+num6)
print(num7+num8)
print(num9+num10)
#subtraction
print("difference between the  given numbers is :")
print(num1-num2)
print(num3-num4)
print(num5-num6)
print(num7-num8)
print(num9-num10)
#multiplication
print("product of the given numbers is : ")
print(num1*num2)
print(num3*num4)
print(num5*num6)
print(num7*num8)
print(num9*num10)
#division
print("division of the given numbers is : ")
print(num1/num2)
print(num3/num4)
print(num5/num6)
print(num7/num8)
print(num9/num10)
#modulus
print("remainder of the given numbers is : ")
print(num1%num2)
print(num3%num4)
print(num5%num6)
print(num7%num8)
print(num9%num10)
#using input method
num1=int(input("enter the first number : "))
num2=int(input("enter the second number : "))
num3=int(input("enter the third number : "))
num4=int(input("enter the fourth number : "))
num5=int(input("enter the fifth number : "))
num6=int(input("enter the sixth number : "))
num7=int(input("enter the seventh number : "))
num8=int(input("enter the eighth number : "))
num9=int(input("enter the ninth number : "))
num10=int(input("enter the tenth number : "))
#addition
print("addition of given numbers is :")
print(num1+num2)
print(num3+num4)
print(num5+num6)
print(num7+num8)
print(num9+num10)
#subtraction
print("difference between the  given numbers is :")
print(num1-num2)
print(num3-num4)
print(num5-num6)
print(num7-num8)
print(num9-num10)
#multiplication
print("product of the given numbers is : ")
print(num1*num2)
print(num3*num4)
print(num5*num6)
print(num7*num8)
print(num9*num10)
#division
print("division of the given numbers is")
print(num1/num2)
print(num3/num4)
print(num5/num6)
print(num7/num8)
print(num9/num10)
#modulus
print("remainder of the given numbers is : ")
print(num1%num2)
print(num3%num4)
print(num5%num6)
print(num7%num8)
print(num9%num10)
# Out:
# addition of given numbers is :
# 9
# 12
# 15
# 24
# 36
# difference between the  given numbers is :
# 3
# 4
# 5
# 8
# 18
# product of the given numbers is :
# 18
# 32
# 50
# 128
# 243
# division of the given numbers is :
# 2.0
# 2.0
# 2.0
# 2.0
# 3.0
# remainder of the given numbers is :
# 0
# 0
# 0
# 0
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-df88d7aa7318> in <cell line: 47>()
#      45 print(num9%num10)
#      46 #using input method
# ---> 47 num1=int(input("enter the first number : "))
#      48 num2=int(input("enter the second number : "))
#      49 num3=int(input("enter the third number : "))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# ...

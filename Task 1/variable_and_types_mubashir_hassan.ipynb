# %%
# String Data Type
name = "Alice"
print(name)

favorite_book = "Pride and Prejudice"
print(favorite_book)

programming_language = "Python"
print(programming_language)

movie_title = "The Shawshank Redemption"
print(movie_title)

song_lyric = "Let it be"
print(song_lyric)

city = "New York City"
print(city)

country = "United States"
print(country)

hobby = "Reading"
print(hobby)

sport = "Soccer"
print(sport)

food = "Pizza"
print(food)

color = "Blue"
print(color)

animal = "Dog"
print(animal)

season = "Autumn"
print(season)

planet = "Earth"
print(planet)

car_brand = "Tesla"
print(car_brand)

phone_brand = "iPhone"
print(phone_brand)

game_genre = "RPG"
print(game_genre)

website = "Google"
print(website)

social_media = "Instagram"
print(social_media)
# Out:
# Alice
# Pride and Prejudice
# Python
# The Shawshank Redemption
# Let it be
# New York City
# United States
# Reading
# Soccer
# Pizza
# Blue
# Dog
# Autumn
# Earth
# Tesla
# iPhone
# RPG
# Google
# Instagram

# %%
# Integer Data Type
age = 30
print(age)

year_born = 1993
print(year_born)

number_of_siblings = 2
print(number_of_siblings)

house_number = 123
print(house_number)

zip_code = 10001
print(zip_code)

phone_number = 1234567890
print(phone_number)

favorite_number = 7
print(favorite_number)

lucky_number = 13
print(lucky_number)

number_of_planets = 8
print(number_of_planets)

number_of_days_in_week = 7
print(number_of_days_in_week)

population_of_india = 1400000000
print(population_of_india)

number_of_countries = 195
print(number_of_countries)

highest_mountain_height = 8848
print(highest_mountain_height)

deepest_ocean_depth = 11034
print(deepest_ocean_depth)

largest_prime_number_known = 2^82589933 - 1
print(largest_prime_number_known)

number_of_stars_in_milky_way = 100000000000
print(number_of_stars_in_milky_way)

age_of_universe = 13800000000
print(age_of_universe)

speed_of_light = 299792458
print(speed_of_light)
# Out:
# 30
# 1993
# 2
# 123
# 10001
# 1234567890
# 7
# 13
# 8
# 7
# 1400000000
# 195
# 8848
# 11034
# 82589934
# 100000000000
# 13800000000
# 299792458

# %%
# Float Data Type
height_cm = 165.5
print(height_cm)

weight_kg = 60.2
print(weight_kg)

pi_value = 3.14159
print(pi_value)

temperature_celsius = 25.6
print(temperature_celsius)

temperature_fahrenheit = 77.9
print(temperature_fahrenheit)

average_grade = 88.75
print(average_grade)

GPA = 3.8
print(GPA)

stock_price = 123.45
print(stock_price)

exchange_rate = 1.12
print(exchange_rate)

interest_rate = 0.05
print(interest_rate)

body_temperature = 37.5
print(body_temperature)

earth_gravity = 9.81
print(earth_gravity)

speed_of_sound = 343.0
print(speed_of_sound)

light_year = 9.461e15
print(light_year)

planck_constant = 6.62607015e-34
print(planck_constant)

avogadro_number = 6.02214076e23
print(avogadro_number)

electron_mass = 9.1093837015e-31
print(electron_mass)

proton_mass = 1.6726219e-27
print(proton_mass)
# Out:
# 165.5
# 60.2
# 3.14159
# 25.6
# 77.9
# 88.75
# 3.8
# 123.45
# 1.12
# 0.05
# 37.5
# 9.81
# 343.0
# 9461000000000000.0
# 6.62607015e-34
# 6.02214076e+23
# 9.1093837015e-31
# 1.6726219e-27

# %%
# Boolean Data Type
is_student = True
print(is_student)

is_employed = False
print(is_employed)

is_married = False
print(is_married)

is_healthy = True
print(is_healthy)

is_happy = True
print(is_happy)

is_raining = False
print(is_raining)

is_sunny = True
print(is_sunny)

is_hot = False
print(is_hot)

is_cold = True
print(is_cold)

is_hungry = False
print(is_hungry)

is_python_fun = True
print(is_python_fun)

is_machine_learning_interesting = True
print(is_machine_learning_interesting)

is_quantum_computing_exciting = True
print(is_quantum_computing_exciting)

is_artificial_intelligence_future = True
print(is_artificial_intelligence_future)

is_climate_change_real = True
print(is_climate_change_real)

is_space_exploration_important = True
print(is_space_exploration_important)

is_renewable_energy_future = True
print(is_renewable_energy_future)

is_education_important = True
print(is_education_important)

is_health_wealth = True
print(is_health_wealth)
# Out:
# True
# False
# False
# True
# True
# False
# True
# False
# True
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# Declare emotions with initial values
Emotions = {
    "Happy": 0,
    "Sad": 0,
    "Grateful": 0,
    "Lonely": 0,
    "Excited": 0,
    "Self_doubt": 0,
    "Angry": 0,
    "Anxious": 0,
    "Repenting": 0,
    "Alexithymia":0
}

# Function to ask for the user's emotion and update the count
def ask_emotion():
    print("Please enter the emotion you are feeling from the following options:")
    options = ["Happy", "Sad", "Grateful", "Lonely", "Excited", "Self_doubt", "Angry", "Anxious", "Repenting","Alexithymia"]
    for option in options:
        print(option)
    while True:
        choice = input("\nChoose an option (Happy, Sad, Grateful, Lonely, Excited, Self_doubt, Angry, Anxious, Repenting,Alexithymia)): ")
        if choice in options:
            Emotions[choice] += 1
            return choice
        else:
            print("Invalid choice. Please choose from the given options.")

# Display welcome message
print("Need emotional assistance? No problem!")
print("Here to let you know you are not alone. Cheer up as we ask ALLAH about our emotions.")
print("Read the words and think about them linkthem to your life")

# Ask for the user's emotion and update the count
user_emotion = ask_emotion()

# Display the updated state of emotions
print("\nUpdated Emotions:")
for emotion, count in Emotions.items():
    print(f"{emotion}: {count}")

# Calculate and display results
print("\nTake a deep breath and connect yourself with the words.")
if Emotions["Happy"] > 0:
    print("And ˹surely˺ your Lord will give so much to you that you will be pleased.")
    print("So Allah will protect them from the evil of that Day\n and give them radiance and happiness")
elif Emotions["Sad"] > 0:
    print("O you who have believed,\n seek help through patience and prayer.\n Indeed, Allah is with the patient.")
    print("And We will surely test you with something of\n fear and hunger and a loss of wealth and lives and fruits,\n but give good tidings to the patient")
    print("So do not weaken and do not grieve,\n and you will be superior\n if you are [true] believers")
    print("Allah does'nt burden a soul more then it can endure")
    print("And let not their speech grieve you.\n Indeed, honor [due to power] belongs to Allah entirely\n He is the Hearing, the Knowing.")
    print("Indeed, after hardship there is ease")
elif Emotions["Grateful"] > 0:
    print("And [remember] when your Lord proclaimed: If you are grateful,\n I will surely increase you [in favor]\n but if you deny,\n indeed, My punishment is severe.")
    print("And be grateful to Me & d0'nt deny Me.\n Reflecting on Allah's blessings can bring a sense of peace & contentment even during lonely times")
    print("Allah has promised the believing men and believing women gardens beneath which rivers flow,\n wherein they abide eternally,\n and pleasant dwellings in gardens of perpetual residence;\n but approval from Allah is greater.\n It is that which is the great attainment.")
elif Emotions["Lonely"] > 0:
    print("You are feeling lonely.")
    print("And be grateful to Me & do'nt deny Me. -\n Reflecting on Allah's blessings can bring a sense of peace & contentment\n even during lonely times")
    print("Indeed, We are closer to him than his jugular vein.\n This verse emphasizes that Allah always near & intimately aware of our feelings,\n including loneliness")
    print("And My mercy encompasses all things.\n This verse reminds us that Allah's mercy is all-encompassing\n and available to us even when we feel alone")
    print("Indeed, after hardship there is ease")
elif Emotions["Excited"] > 0:
    print("The Quran states that praiseworthy joy is to be grateful to God\n for His bounties and to enjoy them.")
    print("The Quran states that worldly joy is blameworthy\n because it is fleeting compared to the hereafter")
elif Emotions["Self_doubt"] > 0:
  print("You are experiencing self-doubt.")
  print("[Some] faces, that Day, will be radiant,(at the day of judgement)")
  print("So that no ˹sinful˺ soul will say ˹on Judgment Day˺, 'Woe to me for neglecting ˹my duties towards˺ Allah, while ridiculing ˹the truth")
  print("Or ˹a soul will˺ say, 'If only Allah had guided me,\n I would have certainly been one of the righteous")
  print("Or say, upon seeing the torment,\n If only I had a second chance\n I would have been one of the good-doers")
elif Emotions["Angry"] > 0:
    print("Be moderate in your pace. And lower your voice for the ugliest of all voices is certainly the braying of donkeys.")
    print("The Prophet also said,\n The strong man is not the good wrestler\n but the strong man is he who controls himself when he is angry")
    print("Those who donate in prosperity and adversity, control their anger,\n and pardon others. And Allah loves the good-doers")
elif Emotions["Anxious"] > 0:
    print(" In the remembrance of Allah do hearts find peace.")
    print(" If you have anxiety, it does not mean your connection with God is weak or\n that you aren’t a good Muslim.\n Having an anxiety disorder is not your fault and it is not something that is easily controlled,\n but there are ways you can manage it and \nthese next few verses from the Holy Quran may help you do just that.")
    print("But they plan and Allah plans and Allah is the best of planners")
    print("O you who have believed, seek help through patience and prayer. Indeed, Allah is with the patient")
    print("Allah is sufficient for us and He is an excellent trustee")
    print("I entrust my affairs unto God. Truly, Allah is aware of His servants")
elif Emotions["Repenting"] > 0:
    print("The Quran states that worldly joy is blameworthy because\n it is fleeting compared to the hereafter")
    print("And whosoever repents and does righteous good deeds,\n then verily, he repents towards Allâh with true repentance.")
    print("But those who committed evil deeds and then repented afterwards and believed,\n verily, your Lord after (all) that is indeed Oft-Forgiving,\n Most Merciful")
elif Emotions["Alexithymia"] > 0:
    print("Do you know some people cannot differenciate between there emotions\n and there is a term for that\n alexithymia\n a personality trait that makes it difficult to\n recognize, understand, and express emotions")
else:
    print("I have got nothing to say ...have a nice day orrr night")
# Out:
# Need emotional assistance? No problem!
# Here to let you know you are not alone. Cheer up as we ask ALLAH about our emotions.
# Read the words and think about them linkthem to your life
# Please enter the emotion you are feeling from the following options:
# Happy
# Sad
# Grateful
# Lonely
# Excited
# Self_doubt
# Angry
# Anxious
# Repenting
# Alexithymia
#
# Choose an option (Happy, Sad, Grateful, Lonely, Excited, Self_doubt, Angry, Anxious, Repenting,Alexithymia)): Alexithymia
#
# Updated Emotions:
# Happy: 0
# Sad: 0
# Grateful: 0
# Lonely: 0
# Excited: 0
# Self_doubt: 0
# Angry: 0
# Anxious: 0
# Repenting: 0
# Alexithymia: 1
#
# Take a deep breath and connect yourself with the words.
# Do you know some people cannot differenciate between there emotions
#  and there is a term for that
#  alexithymia
#  a personality trait that makes it difficult to
#  recognize, understand, and express emotions

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Example dataset creation (assuming you don't have a real dataset)
# For this example, we'll create a simple synthetic dataset related to HIV detection

data = {
    'Age': [25, 30, 45, 50, 23, 40, 35, 60, 70, 55],    # Age of the individual
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],  # Gender
    'Fever': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0],  # Fever (1 for Yes, 0 for No)
    'Fatigue': [1, 0, 1, 1, 0, 1, 1, 0, 1, 0],  # Fatigue (1 for Yes, 0 for No)
    'Cough': [0, 0, 1, 0, 0, 1, 0, 1, 1, 0],  # Cough (1 for Yes, 0 for No)
    'HIV': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0]   # HIV status (1 for Positive, 0 for Negative)
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Convert categorical 'Gender' to numeric (Male = 0, Female = 1)
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# Define features (X) and target variable (y)
X = df[['Age', 'Gender', 'Fever', 'Fatigue', 'Cough']]  # Features
y = df['HIV']  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Plot the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=['Negative', 'Positive'], filled=True, rounded=True)
plt.title("Decision Tree for HIV Prediction")
plt.show()
# 1st
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Example dataset creation (assuming you don't have a real dataset)
# For this example, we'll create a simple synthetic dataset related to HIV detection

data = {
    'Age': [25, 30, 45, 50, 23, 40, 35, 60, 70, 55],    # Age of the individual
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],  # Gender
    'Fever': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0],  # Fever (1 for Yes, 0 for No)
    'Fatigue': [1, 0, 1, 1, 0, 1, 1, 0, 1, 0],  # Fatigue (1 for Yes, 0 for No)
    'Cough': [0, 0, 1, 0, 0, 1, 0, 1, 1, 0],  # Cough (1 for Yes, 0 for No)
    'HIV': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0]   # HIV status (1 for Positive, 0 for Negative)
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Convert categorical 'Gender' to numeric (Male = 0, Female = 1)
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# Define features (X) and target variable (y)
X = df[['Age', 'Gender', 'Fever', 'Fatigue', 'Cough']]  # Features
y = df['HIV']  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=23)

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=23)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=['Negative', 'Positive'], filled=True, rounded=True)
plt.title("Decision Tree for HIV Prediction")
plt.show()
#2nd
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Example dataset creation (assuming you don't have a real dataset)
# For this example, we'll create a simple synthetic dataset related to HIV detection

data = {
    'Age': [25, 30, 45, 50, 23, 40, 35, 60, 70, 55],    # Age of the individual
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],  # Gender
    'Fever': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0],  # Fever (1 for Yes, 0 for No)
    'Fatigue': [1, 0, 1, 1, 0, 1, 1, 0, 1, 0],  # Fatigue (1 for Yes, 0 for No)
    'Cough': [0, 0, 1, 0, 0, 1, 0, 1, 1, 0],  # Cough (1 for Yes, 0 for No)
    'HIV': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0]   # HIV status (1 for Positive, 0 for Negative)
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Convert categorical 'Gender' to numeric (Male = 0, Female = 1)
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# Define features (X) and target variable (y)
X = df[['Age', 'Gender', 'Fever', 'Fatigue', 'Cough']]  # Features
y = df['HIV']  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))



# Plot the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=['Negative', 'Positive'], filled=True, rounded=True)
plt.title("Decision Tree for HIV Prediction")
plt.show()
# 3rd
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Example dataset creation (assuming you don't have a real dataset)
# For this example, we'll create a simple synthetic dataset related to HIV detection

data = {
    'Age': [25, 30, 45, 50, 23, 40, 35, 60, 70, 55],    # Age of the individual
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],  # Gender
    'Fever': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0],  # Fever (1 for Yes, 0 for No)
    'Fatigue': [1, 0, 1, 1, 0, 1, 1, 0, 1, 0],  # Fatigue (1 for Yes, 0 for No)
    'Cough': [0, 0, 1, 0, 0, 1, 0, 1, 1, 0],  # Cough (1 for Yes, 0 for No)
    'HIV': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0]   # HIV status (1 for Positive, 0 for Negative)
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Convert categorical 'Gender' to numeric (Male = 0, Female = 1)
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# Define features (X) and target variable (y)
X = df[['Age', 'Gender', 'Fever', 'Fatigue', 'Cough']]  # Features
y = df['HIV']  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=332)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Plot the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=['Negative', 'Positive'], filled=True, rounded=True)
plt.title("Decision Tree for HIV Prediction")
plt.show()
# 4th
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Example dataset creation

data = {
    'Age': [25, 30, 45, 50, 23, 40, 35, 60, 70, 55],    # Age of the individual
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Female'],  # Gender
    'Fever': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0],  # Fever (1 for Yes, 0 for No)
    'Fatigue': [1, 0, 1, 1, 0, 1, 1, 0, 1, 0],  # Fatigue (1 for Yes, 0 for No)
    'Cough': [0, 0, 1, 0, 0, 1, 0, 1, 1, 0],  # Cough (1 for Yes, 0 for No)
    'HIV': [1, 0, 1, 0, 1, 0, 0, 1, 1, 0]   # HIV status (1 for Positive, 0 for Negative)
}

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Convert categorical 'Gender' to numeric (Male = 0, Female = 1)
df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# Define features (X) and target variable (y)
X = df[['Age', 'Gender', 'Fever', 'Fatigue', 'Cough']]  # Features
y = df['HIV']  # Target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dt_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Plot the Decision Tree
plt.figure(figsize=(12, 8))
plot_tree(dt_model, feature_names=X.columns, class_names=['Negative', 'Positive'], filled=True, rounded=True)
plt.title("Decision Tree for HIV Prediction")
plt.show()
# Out:
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Confusion Matrix:
# [[2 0]
#  [0 2]]
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
# Accuracy: 1.0
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
# ...

# %% [markdown]
# # **Multilater preceptron.**

# %% [markdown]
# # Example

# %%
#hidden layer 2

qualification=int(input("enter your qualification"))
marks=int(input("enter your marks"))
potential=int(input("enter your potential"))
personality=int(input(" enter personality"))



print (" hdden layer 2 preceptron.")


#node1
w1_1_1=0.2
w1_1_2=3.3
w1_1_3=2.2
w1_1_4=2.5

#node2
w1_2_1=0.1
w1_2_2=3.7
w1_2_3=2.2
w1_2_4=2.5

#node3
w1_3_1=3.3
w1_3_2=1.4
w1_3_3=1.5
w1_3_4=1.1


#node#4
w1_4_1=3.3
w1_4_2=1.4
w1_4_3=1.5
w1_4_4=1.1


#node#5
w1_5_1=3.3
w1_5_2=1.4
w1_5_3=1.5
w1_5_4=1.1



result_1 = (qualification * w1_1_1) + (marks* w1_1_2) + (potential * w1_1_3) + (personlality * w1_1_4)
print(result_1)

result_2 =  (qualification * w1_2_1) + (marks * w1_2_3) + ( potential* w1_2_3) + (marks * w1_2_4)
print(result_2)

result_3 =  ( qualification* w1_3_1) + (marks * w1_3_2) + (potential * w1_3_3) + (personality * w1_3_4)
print(result_3)

result_4 =  (qualification * w1_4_1) + (marks * w1_4_2) + (potential * w1_4_3) + (personality * w1_4_4)
print(result_4)

result_5 =  (qualification* w1_5_1) + (marks * w1_5_2) + (potential * w1_5_3) + (personality * w1_5_4)
print(result_5)



final_result_layer1 = (result_1+result_2+result_3+result_4+result_5)

print(final_result_layer1)




# hidden layear 2



#node1
w2_1_1=0.2
w2_1_2=3.3
w2_1_3=2.2
w2_1_4=2.5

#node2
w2_2_1=0.1
w2_2_2=3.2
w2_2_3=2.2
w2_2_4=2.5

#node3
w2_3_1=3.2
w2_3_2=1.4
w2_3_3=1.3
w2_3_4=1.5


#node#4
w2_4_1=3.2
w2_4_2=1.2
w2_4_3=1.4
w2_4_4=1.2


#node#5
w2_5_1=3.5
w2_5_2=1.3
w2_5_3=1.3
w2_5_4=1




result_1 = (qualification * w2_1_1) + (marks* w2_1_2) + (potential * w2_1_3) + (personlality * w2_1_4)
print(result_1)

result_2 =  (qualification * w2_2_1) + (marks * w2_2_3) + ( potential* w2_2_3) + (marks * w2_2_4)
print(result_2)

result_3 =  ( qualification* w2_3_1) + (marks * w2_3_2) + (potential * w2_3_3) + (personality * w2_3_4)
print(result_3)

result_4 =  (qualification * w2_4_1) + (marks * w2_4_2) + (potential * w2_4_3) + (personality * w2_4_4)
print(result_4)

result_5 =  (qualification* w2_5_1) + (marks * w2_5_2) + (potential * w2_5_3) + (personality * w2_5_4)
print(result_5)



final_result_layer2 = (result_1+result_2+result_3+result_4+result_5)

print(final_result_layer2)





#hidden layer 3




#node1
w3_1_1=0.2
w3_1_2=3.3
w3_1_3=2.2
w3_1_4=2.5

#node2
w3_2_1=0.1
w3_2_2=3.2
w3_2_3=2.2
w3_2_4=2.5

#node3
w3_3_1=3.2
w3_3_2=1.4
w3_3_3=1.3
w3_3_4=1.5


#node#4
w3_4_1=3.2
w3_4_2=1.2
w3_4_3=1.4
w3_4_4=1.2


#node#5
w3_5_1=3.5
w3_5_2=1.3
w3_5_3=1.3
w3_5_4=1




result_1 = (qualification * w3_1_1) + (marks* w3_1_2) + (potential * w3_1_3) + (personlality * w3_1_4)
print(result_1)

result_2 =  (qualification * w3_2_1) + (marks * w3_2_3) + ( potential* w3_2_3) + (marks * w3_2_4)
print(result_2)

result_3 =  ( qualification* w3_3_1) + (marks * w3_3_2) + (potential * w3_3_3) + (personality * w3_3_4)
print(result_3)

result_4 =  (qualification * w3_4_1) + (marks * w3_4_2) + (potential * w3_4_3) + (personality * w3_4_4)
print(result_4)

result_5 =  (qualification* w3_5_1) + (marks * w3_5_2) + (potential * w3_5_3) + (personality * w3_5_4)
print(result_5)


#output_layer_3
final_result_layer3 = (result_1+result_2+result_3+result_4+result_5)

print(final_result_layer1)

# %% [markdown]
# # hidden layer 1

# %%
glaxayStar1=int(input("enter the star1:"))
glaxayStar2=int(input("enter the star2:"))
glaxayStar3=int(input("enter the star3:"))
glaxayStar4=int(input("enter the star4:"))


#node1
w3_1_1=0.2
w3_1_2=3.3
w3_1_3=2.2
w3_1_4=2.5

#node2
w3_2_1=0.1
w3_2_2=3.2
w3_2_3=2.2
w3_2_4=2.5

#node3
w3_3_1=3.2
w3_3_2=1.4
w3_3_3=1.3
w3_3_4=1.5


#node#4
w3_4_1=3.2
w3_4_2=1.2
w3_4_3=1.4
w3_4_4=1.2


#node#5
w3_5_1=3.5
w3_5_2=1.3
w3_5_3=1.3
w3_5_4=1





result_1 =( glaxayStar_1* w1_1_1) + (glaxayStar_2* w1_1_2) + (glaxayStar_3 * w1_1_3) + (GlaxayStar_4 * w1_1_4)
print(result_1)

result_2 = ( glaxayStar_1* w2_1_1) + (glaxayStar_2* w2_1_2) + (glaxayStar_3 * w2_1_3) + (GlaxayStar_4 * w2_1_4)
print(result_2)

result_3 = ( glaxayStar_1* w3_1_1) + (glaxayStar_2* w3_1_2) + (glaxayStar_3 * w3_1_3) + (GlaxayStar_4 * w3_1_4)
print(result_3)

result_4 = ( glaxayStar_1* w4_1_1) + (glaxayStar_2* w4_1_2) + (glaxayStar_3 * w4_1_3) + (GlaxayStar_4 * w4_1_4)
print(result_4)

result_5 = ( glaxayStar_1* w5_1_1) + (glaxayStar_2* w5_1_2) + (glaxayStar_3 * w5_1_3) + (GlaxayStar_4 * w5_1_4)
print(result_5)


#output_layer_1
final_result_layer1 = (result_1+result_2+result_3+result_4+result_5)

print(final_result_layer1)





#hidden layer 2



#node1
w1_11_1=0.2
w1_11_2=3.3
w1_11_3=2.2
w1_11_4=2.5

#node2
w1_22_1=0.1
w1_22_2=3.7
w1_22_3=2.2
w1_22_4=2.5

#node3
w1_33_1=3.3
w1_33_2=1.4
w1_33_3=1.5
w1_33_4=1.1


#node#4
w1_44_1=3.3
w1_44_2=1.4
w1_44_3=1.5
w1_44_4=1.1


#node#5
w1_55_1=3.3
w1_55_2=1.4
w1_55_3=1.5
w1_55_4=1.1




result_1 =( glaxayStar_1* w1_11_1) + (glaxayStar_2* w1_11_2) + (glaxayStar_3 * w1_11_3) + (GlaxayStar_4 * w1_11_4)
print(result_1)

result_2 = ( glaxayStar_1* w2_22_1) + (glaxayStar_2* w2_22_2) + (glaxayStar_3 * w2_22_3) + (GlaxayStar_4 * w2_22_4)
print(result_2)

result_3 = ( glaxayStar_1* w3_33_1) + (glaxayStar_2* w3_33_2) + (glaxayStar_3 * w3_33_3) + (GlaxayStar_4 * w3_33_4)
print(result_3)

result_4 = ( glaxayStar_1* w4_44_1) + (glaxayStar_2* w4_44_2) + (glaxayStar_3 * w4_44_3) + (GlaxayStar_4 * w4_44_4)
print(result_4)

result_5 = ( glaxayStar_1* w5_55_1) + (glaxayStar_2* w5_55_2) + (glaxayStar_3 * w5_55_3) + (GlaxayStar_4 * w5_55_4)
print(result_5)


#output_layer_2
final_result_layer2 = (result_1+result_2+result_3+result_4+result_5)

print(final_result_layer2)

# %% [markdown]
# # the end

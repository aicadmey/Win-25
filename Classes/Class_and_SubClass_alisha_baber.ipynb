# %% [markdown]
# # Create classes and sub classes till 5th class.

# %% [markdown]
# **CLASS 1**

# %%
# class 1
class human:
  #sub class 1
  class student:
    def __init__(self,gender):
     self.gender="gender"
    def display(self):
      print(f"student human : {self.gender}")
      student=human.student("female")
      student.display()

# %% [markdown]
# **CLASS 2**

# %%
#CLASS 1
class person:
#SUB CLASS 1
   class driver:
    def __init__(self,age):
     self.age="age"
    def display(self):
      print(f"driver person :{self.age}")
      driver=person.driver("30")
      driver.display()
# SUB CLASS 2
    class employee
    def __init__(self,work):
     self.work="work"
    def display(self):
      print(f"employee person:"{ self.work})
      employee=person.employee("manager")
      employee.display()

#class 2
class kingdom:
#SUB CLASS 1
 class specie:
      def __init__(self, name):
       self.name="name"
      def display(self):
       print(f"specie kingdom :{self.name}")
      specie=kingdom.specie("bionomial")
      specie.display()

#SUB CLASS 2
class human:
  def __init__(self,gender):
    self.gender="gender"
    def display(self):
      print(f"human kingdom: {self.gender}"))
      human=kingdom.human ("male")
      human.display()

# %% [markdown]
#  **Class 3**

# %%
#CLASS 1
class organism :
  #SUB CLASS 1
    class reptiles:
      def __init__(self,gernations):
        self.gernations="gernations"
      def display(self):
        print(f"reptiles organism :{self.gernations}")
        reptiles=organism.reptiles("parent")
        reptiles.display()
#SUB CLASS 2
class mamals:
  def __init__(self,legs):
    self.legs="legs"
    def display(self):
      print(f"mamals organism:{self.legs}")
      mamals=organism.mamals("four")
      mamals.display()
#SUB CLASS 3
class birds:
  def __init__(self,specie):
    self.specie="specie"
    def disply(self):
      print(f"birds organisms:{self.specie}")
      birds=organism.birds("parrot")
      birds.display()


#CLASS 2
class vehical:
#SUB CLASS 1
 class car:
  def __init__(self,brand):
   self.brand="brand"
   def display(self):
    print(f"car vehical:{self.brand}")
    car=vehical.car("bmw")
    car.display()
#SUB CLASS 2
class bike:
  def __init__(self,color):
    self.color="color"
    def display(self):
      print(f"bike vehical:{self.color}")
      bike=vehical.bike("red")
      bike.display()
#SUB CLASS 3
class cycle:
  def __init__(self,color):
   self.color="color"
  def display(self):
    print(f"cycle vehical:{self.color}")
    cycle=vehical.cycle("green")
    cycle.display()



#CLASS 3
class Library:
#SUB CLASS 1
 class novels:
  def __init__ (self, pages):
   self.pages="pages"
  def display(self):
    print(f"novels library:{self.pages}")
    novels=Library.novels("200")
    novels.display()
# SUB CLASS 2
class dictionery:
  def __init__(self,word):
    self.word="word"
    def display(self):
      print(f"dictionery library:{self.word}")
      dictionery=Library.dictionery("book")
      dictionery.display()
#SUB CLASS 3
class islamicBooks:
  def __init__(self,hadith):
    self.hadith="hadith"
    def display(self):
      print(f"islamicBooks library:{self.hadith}")
      islamicBooks=Library.islamicBooks("sunnah")
      islamicBooks.display()

# %% [markdown]
#  **CLASS 4**

# %%
#CLASS 1
class building:
#SUB CLASS 1
class room:
  def __init__(self,quantity):
    self.quantity="quantity"
    def display(self):
      print(f"room building:{self.quantity}")
      room=building.room("4")
      room.display()
#SUB CLASS 2
class kitchen:
  def __init__(self,paint):
  self.paint="paint"
  def display(self):
    print(f"kitchen building:"{self.paint})
    kitchen=building.kitchen("off white")
    kitchen.display()
#SUB CLASS 3
class washroom:
  def __init__(self,water):
  self.water="water"
  def display(self):
    print(f"washroom building:{self.water}")
    washroom=building.washroom("hot water")
    washroom.display()
#SUB CLASS 4
class garage:
  def __init__(self,car):
   self.car="car"
   def display(self):
    print(f"garage building:{self.car}")
    garage=building.garage("jeep")
    garage.display()




#CLASS 2
class hospital:
#SUB CLASS 1
class doctors:
  def __init__ (self,personality):
   self.personality="personality"
  def display(self):
    print(f"doctors hospital:{self.personality}")
    doctors=hospital.doctors("friendly")
    doctors.display()
#SUB CLASS 2
class nurse:
  def __init__(self,uniformColor):
    self.uniformColor="uniformColor"
    def display(self):
    print(f"nurse hospital:"{self.uniformColor})
    nurse=hospital.nurse("white and navy blue")
    nurse display()
#SUB CLASS 3
class paitent:
  def __init__(self,health):
  self.health="health"
  def display(self):
  print( f"paitent hospital:"{self.health})
  paitent=hospital.paitent(" sick")
  paitent dispaly()
# SUB CLASS 4
class ICU:
  def __init__(self,rooms):
  self.rooms="rooms"
  def display(self):
  print(f"ICU hospital:"{self.rooms})
  ICU=hospital.ICU("100")
  ICU display()


# CLASS 3
class garden:
#SUB CLASS 1
class Flower:
  def __init__(self,color):
    self.color="color"
    def display(self):
      print(f"Flower garden:{self.color}")
      Flower=garden.Flower("red")
      Flower.display()
 #SUB CLASS 2
 class Tree:
  def __init__(self, type):
  self.type="type"
  def display(self):
   print(f" tree garden:{self.type}")
   tree=garden.tree("pine")
   tree.display()
# SUB CLASS 3
class shurb:
  def __init__(self,color):
  self.color="color"
  def display(self):
  print(f"shurb garden:{self.color}")
  shurb=garden.shurb("green")
  shurb.display()
# SUB CLASS 4
class vegetables:
  def __init__(self,color):
  self.color="color
  def display(self):
  print(f"vegetables garden:{self.color}")
  vegetables=garden.vegetables("green")
  vegetables.display()





#CLASS 4
class universe:
#SUB CLASS 1
class glaxay:
  def __init__(self,size):
  self.size="size"
  def display(self):
  print(f"glaxay universe:{self.size}")
  glaxay=universe.glaxay("none")
#SUB CLASS 2
class star:
  def __init__(self,color):
  self.color="color"
  def display(self):
  print(f"star universe:{self.color}")
  star=universe.star("yellow")
  star.display()
#SUB CLASS 3
class planet:
  def __init__(self,name):
  self.name="name"
  def display(self):
    print(f"planet universe:{self.name}")
    planet=universe.planet("earth")
    planet.display()
#SUB CLASS 4
class blackHole:
  def __init__(self,size):
  self.name="size"
  def display(self):
    print(f"blackHole universe:{self.size}")
  blackHole=universe.blackHole(" 4.5")
  blackHole.display()

# %% [markdown]
# **CLASS 5**

# %%
#CLASS 1
class hacking:
#SUB CLASS 1
class ethecialHacker:
  def __init__(self,name):
    self.name="name"
    def display(self):
      print(f"ethecialHacker hacking:{self.name}")
      ethecialHacker=hacking.ethecialHacker("hacker")
      ethecialHacker.display
#SUB CLASS 2
class BlackHatHacker :
  def __init__(self,target):
  self.target="target"
  def display(self):
    print(f" blackHatHacker hacking:"{self.target})
    blackHatHacker=hacking.blackHatHacker("bank server")
    blackHatHacker.display()
#SUB CLASS 3
class cyberSeacurity:
  def __init__(self,certification):
  self.certification="certification"
  def display(self):
    print(f"cyberSeacurity hacking:{self.certification}")
    cyberSeacurity=hacking.cyberSeacurity("certified")
    cyberSeacurity.display()
#SUB CLASS 4
class ScriptKiddie:
  def __init__(self,language):
  self.language="language"
  def display(self):
    print(f"ScriptKiddie hacking:{self.language}")
    ScriptKiddie=hacking.ScriptKiddie("python")
    ScriptKiddie.display()
#SUB CLASS 5
class  Hacktivist :
  def __init__(self,name):
  self.name="name"
  def display(self):
    print(f"Hacktivist hacking:{self.name}")
    Hacktivist=hacking.Hacktivist("hacker")
    Hacktivist.display()



#CLASS 2
class bakery:
#SUB CLASS 1
class bread:
  def __init__(self,type):
  self.type="type"
  def display(self):
    print(f"bread bakery:{self.type}")
    bread=bakery.bread("white")
    bread.display()
#SUB CLASS 2
class cookie:
  def __init__(self,color):
  self.color="color"
  def display(self):
    print(f"cookie bakery:{self.color}")
    cookie=bakery.cookie("brown")
    cookie.display()
# SUB CLASS 3
class oatmeal:
  def __init__(self,size):
  self.size="size"
  def display(self):
    print(f"oatmeal bakery:{self.size}")
    oatmeal=bakery.oatmeal("small")
    oatmeal.display()
# SUB CLASS 4
class muffin:
  def __init__(self,shape):
  self.shape="shape"
  def display(self):
    print(f"muffin bakery:{self.shape}")
    muffin=bakery.muffin("round")
    muffin.display()
#SUB CLASS 5
class cake:
  def __init__(self,ponds)
  self.ponds="ponds"
  def dislay(self):
    print(f" cake bakery:{self.ponds}")
    cake=bakery.cake("4")
    cake.display()







# class 3
class computer:
#SUB CLASS 1
class laptop:
  def __init__(self,brand):
  self.brand="brand"
  def display(self):
    print(f"laptop computer:{self.brand}")
    laptop=computer.laptop("dell")
    laptop.display()
# SUB CLASS 2
class ultraBook:
  def __init__(self,color):
  self.color="color"
  def display(self):
    print(f"ultraBook computer:{self.color}")
    ultraBook=computer.ultraBook("black")
    ultra.display()
#SUB CLASS 3
class tab:
  def __init__(self,modle):
  self.modle="modle"
  def display(self):
    print(f"tab computer:{self.modle}")
    tab=computer.tab("10")
    tab.display()
#SUB CLASS 4
class mobile:
  def __init__(self,name):
    self.name="name"
    def display(self):
      print(f"mobile computer:{self.name}")
      mobile=computer.mobile("samsung")
      mobile.display
#SUN CLASS 5
class workstation:
  def __init__(self,size):
  self.size="size"
  def display(self):
    print(f"workstation computer:{self.size}")
    workstation=computer.workstation("large")
    workstation.display()






#class 4
class Fish:
#SUB CLASSS 1
class whale:
  def__init__(self,name):
    self.name="name"
    def display(self):
      print(f"fish aquarium:{self.name}")
      fish=aquarium.fish("salmon")
      fish.display()
# SUB CLASS 2
class shark:
  def __init__(self,color):
  self.color="color"
  def display(self):
    print(f"shark aquarium:{self.color}")
    shark=aquarium.shark("grey")
    shark.display()
# SUB CLASS 3
class starfish:
  def __init__(self,size):
  self.size="size"
  def display(self):
    print(f"starfish aquarium:{self.size}")
    starfish=aquarium.starfish("small")
    starfish.display()
# SUB CLASS 4
class freshFish:
  def __init__(self, age):
    self.age="age"
    def display(self):
      print(f"freshFish aquarium:{self.age}")
      freshFish=aquarium.freshFish("fresh")
      freshFish.display()
# SUB CLASS 5
class bonyFish:
  def __init__(self,sakeltonBones):
    self.sakeltonBones="sakeltonBones"
          def display(self):
            print(f"bonyFish aquarium:{self.sakeltonBones}")
            bonyFish=aquarium.bonyFish("bones")
            bonyFish.display()






#class 5

class Shop:
# SUB CLASS 1
class crockery:
  def __init__(self,name):
    self.name="name"
    def display(self):
      print(f"crockery shop:{self.name}")
      crockery=Shop.crockery("A wala store")
      crockery.display()
# SUB CLASS 2
class barber:
        def __init__(self,name):
          self.name="name"
          def display(self):
            print(f"barber shop:{self.name}")
            barber=Shop.barber("barber shop")
            barber.display()
# Sub class 3
class clothes:
  def __init__(self,color):
    self.color="color"
    def display(self):
      print(f"clothes shop:{self.color}")
      clothes=Shop.clothes("white")
      clothes.display()
#SUB CLASS 4
class shoe:
  def __init__(self,brand):
    self.brand="brand"
    def display(self):
      print(f"shoe shop:{self.brand}")
      shoe=Shop.shoe("nike")
      shoe.display()
#SUB CLASS 5
class jewellery:
  def __init__(self,type):
    self.type="type"
    def display(self):
      print(f"jewellery shop:{self.type}")
      jewellery=Shop.jewellery("necklace")
      jewellery.display()

# %% [markdown]
# # **Finally Finish**

# %%
# Train a logistic regression classifier to predict whether a flower is iris virginica or not
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(iris['DESCR'])

X = iris["data"][:, 3:]
# Use int instead of np.int
y = (iris["target"] == 2).astype(int) # Changed this line

# Train a logistic regression classifier
clf = LogisticRegression()
clf.fit(X,y)
example = clf.predict(([[2.6]]))
print(example)

# Using matplotlib to plot the visualization
X_new = np.linspace(0,3,1000).reshape(-1,1)
y_prob = clf.predict_proba(X_new)
print(y_prob)
plt.plot(X_new, y_prob[:,1], "g-", label="virginica")
plt.show()


# print(y)
# print(iris["data"])
# print(X)
# Out:
# [1]
# [[9.99249051e-01 7.50949397e-04]
#  [9.99239224e-01 7.60776030e-04]
#  [9.99229269e-01 7.70731151e-04]
#  ...
#  [3.08499021e-03 9.96915010e-01]
#  [3.04523414e-03 9.96954766e-01]
#  [3.00598887e-03 9.96994011e-01]]

# %%
# Train a logistic regression classifier to predict whether a flower is iris virginica or not
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(iris['DESCR'])

X = iris["data"][:, 2:] # Selecting petal length and petal width as features
# Use int instead of np.int
y = (iris["target"] == 1).astype(int) # Changed this line

# Train a logistic regression classifier
clf = LogisticRegression()
clf.fit(X,y)
# example = clf.predict(([[2.6]])) # This line was causing the error
# Providing two features for prediction, corresponding to petal length and width
example = clf.predict(([[2.6, 1.5]]))
print(example)

# Using matplotlib to plot the visualization
X_new = np.linspace(0,1,1000).reshape(-1,1) # this only produces values for petal length (one feature)
# We need to create data for both features (petal length and width)
# Here, we'll keep petal width fixed at 1.5 and vary petal length
X_new = np.column_stack([np.linspace(0, 7, 1000), np.full(1000, 1.5)]) # Create data for both features
y_prob = clf.predict_proba(X_new)
print(y_prob)
plt.plot(X_new[:, 0], y_prob[:,1], "g-", label="virginica") # Plot using petal length on x-axis
plt.xlabel("Petal length (cm)")
plt.ylabel("Probability of being Iris-versicolor")
plt.show()


# print(y)
# print(iris["data"])
# print(X)
# Out:
# [0]
# [[0.98931123 0.01068877]
#  [0.98924539 0.01075461]
#  [0.98917915 0.01082085]
#  ...
#  [0.15968447 0.84031553]
#  [0.15885334 0.84114666]
#  [0.15802572 0.84197428]]

# %%
# Train a logistic regression classifier to predict whether a flower is iris virginica or not
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(iris['DESCR'])

X = iris["data"][:, 1:]
# Use int instead of np.int
y = (iris["target"] == 1).astype(int) # Changed this line

# Train a logistic regression classifier
clf = LogisticRegression()
clf.fit(X,y)
# The model was trained on 3 features, so we need to provide 3 features for prediction
# example = clf.predict(([[0.6]]))
example = clf.predict(([[0.6, 1.5, 0.2]])) # Example with 3 features: sepal width, petal length, petal width
print(example)

# Using matplotlib to plot the visualization
# X_new = np.linspace(0,3,1000).reshape(-1,1) # This creates data for only one feature
# To visualize the decision boundary, we need to vary all 3 features
# Here, we'll keep sepal width and petal width fixed and vary petal length
X_new = np.column_stack([np.full(1000, 0.6), np.linspace(0, 7, 1000), np.full(1000, 0.2)]) # Data for 3 features
y_prob = clf.predict_proba(X_new)
print(y_prob)
plt.plot(X_new[:, 1], y_prob[:,1], "g-", label="virginica") # Plot using petal length on x-axis
plt.xlabel("Petal length (cm)")
plt.ylabel("Probability of being Iris-versicolor")
plt.show()


# print(y)
# print(iris["data"])
# print(X)
# Out:
# [1]
# [[2.80673508e-02 9.71932649e-01]
#  [2.79533654e-02 9.72046635e-01]
#  [2.78398297e-02 9.72160170e-01]
#  ...
#  [4.44197543e-04 9.99555802e-01]
#  [4.42342539e-04 9.99557657e-01]
#  [4.40495279e-04 9.99559505e-01]]

# %%
# Train a logistic regression classifier to predict whether a flower is iris virginica or not
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(iris['DESCR'])

X = iris["data"][:, 3:]  # Selecting only the 4th feature (petal width)
# Use int instead of np.int
# The target should be whether the flower is Iris-virginica (class 2) or not
y = (iris["target"] == 2).astype(int)  # Changed this line to correctly identify Iris-virginica

# Train a logistic regression classifier
clf = LogisticRegression()
clf.fit(X,y)
# The model was trained on only petal width, so we need to provide petal width for prediction
example = clf.predict(([[2.6]]))  # Example with petal width 2.6
print(example)

# Using matplotlib to plot the visualization
X_new = np.linspace(0,3,1000).reshape(-1,1) # This creates data for petal width
y_prob = clf.predict_proba(X_new)
print(y_prob)
plt.plot(X_new, y_prob[:,1], "g-", label="virginica") # Plot using petal width on x-axis
plt.xlabel("Petal width (cm)") # Changed x-axis label
plt.ylabel("Probability of being Iris-virginica") # Changed y-axis label
plt.show()


# print(y)
# print(iris["data"])
# print(X)
# Out:
# [1]
# [[9.99249051e-01 7.50949397e-04]
#  [9.99239224e-01 7.60776030e-04]
#  [9.99229269e-01 7.70731151e-04]
#  ...
#  [3.08499021e-03 9.96915010e-01]
#  [3.04523414e-03 9.96954766e-01]
#  [3.00598887e-03 9.96994011e-01]]

# %%
# Train a logistic regression classifier to predict whether a flower is iris virginica or not
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
iris = datasets.load_iris()
# print(list(iris.keys()))
# print(iris['data'].shape)
# print(iris['target'])
# print(iris['DESCR'])

X = iris["data"][:, 0:]  # Selecting all 4 features
# Use int instead of np.int
# The target should be whether the flower is Iris-virginica (class 2) or not
y = (iris["target"] == 1).astype(int)  # Changed this line to correctly identify Iris-virginica

# Train a logistic regression classifier
clf = LogisticRegression()
clf.fit(X,y)
# The model was trained on 4 features, so we need to provide all 4 features for prediction
# example = clf.predict(([[2.6]]))  # This was incorrect as it provided only 1 feature
example = clf.predict(([[5.1, 3.5, 1.4, 0.2]]))  # Example with all 4 features
print(example)

# Using matplotlib to plot the visualization
# X_new
# Out:
# [0]

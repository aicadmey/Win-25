# %%
# SYEDA ZAINAB FATIMA
# W25-PAK-INP-AI-01

# %%
# LINEAR REGRESSION EXPERIMENTS

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate random data
X = np.random.rand(10, 1)  # 10 random points
y = 2 * X + 1 + np.random.randn(10, 1)  # y = 2x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[1.26788655]], Intercept: [1.83182156]

# %%
# Generate random data
X = np.random.rand(5, 1)  # 5 random points
y = 2 * X + 1 + np.random.randn(5, 1)  # y = 2x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[3.15506613]], Intercept: [-0.79308431]

# %%
# Generate random data
X = np.random.rand(20, 1)  # 20 random points
y = 2 * X + 1 + np.random.randn(20, 1)  # y = 2x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[2.07134327]], Intercept: [0.82010377]

# %%
# Generate random data
X = np.random.rand(20, 1)  # 20 random points
y = 5 * X + 1 + np.random.randn(20, 1)  # y = 5x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(X, y)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[4.61373086]], Intercept: [0.98195038]

# %%
# Generate random data
X = np.random.rand(5, 1)  # 5 random points
y = 10 * X + 1 + np.random.randn(5, 1)  # y = 10x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(y, X)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[0.09076469]], Intercept: [-0.0699127]

# %%
# Generate random data
X = np.random.rand(5, 1)  # 5 random points
y = 5 * X + 1 + np.random.randn(5, 1)  # y = 5x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(y, X)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[0.03307654]], Intercept: [0.34406819]

# %%
# Generate random data
X = np.random.rand(25, 1)  # 25 random points
y = 50 * X + 1 + np.random.randn(25, 1)  # y = 50x + 1 + noise

# Fit linear regression model
model = LinearRegression()
model.fit(y, X)

# Predictions
y_pred = model.predict(X)

# Plotting the data and the regression line
plt.scatter(X, y, color='blue')
plt.plot(X, y_pred, color='red')
plt.title("Simple Linear Regression")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

print(f"Coefficient: {model.coef_}, Intercept: {model.intercept_}")
# Out:
# Coefficient: [[0.01980311]], Intercept: [-0.01185705]
